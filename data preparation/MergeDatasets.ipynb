# %%
# Import pandas library
import pandas as pd

# %%
# Load all the cleaned datasets along with the original Recipes dataset
recipes = pd.read_csv('C:/Users/SLL26/Desktop/Data Science and Analytics/CS5706 MACHINE LEARNING/CS5811 Coursework/recipes.csv')
ingredientsCount = pd.read_csv('C:/Users/SLL26/Desktop/Data Science and Analytics/CS5706 MACHINE LEARNING/CS5811 Coursework/Cleaned CSV/Ingredient.csv')
minMaxMean = pd.read_csv('C:/Users/SLL26/Desktop/Data Science and Analytics/CS5706 MACHINE LEARNING/CS5811 Coursework/Cleaned CSV/MinMax.csv')
timeFormat = pd.read_csv('C:/Users/SLL26/Desktop/Data Science and Analytics/CS5706 MACHINE LEARNING/CS5811 Coursework/Cleaned CSV/TimeFormat.csv')
reviewclean = pd.read_csv('C:/Users/SLL26/Desktop/Data Science and Analytics/CS5706 MACHINE LEARNING/CS5811 Coursework/Cleaned CSV/clean_review.csv')

# %%
# View head values for all the datasets
recipes.head(3)
# Out:
#    RecipeId                               Name  AuthorId      AuthorName  \
# 0        38  Low-Fat Berry Blue Frozen Dessert      1533          Dancer
# 1        39                            Biryani      1567        elly9812
# 2        40                      Best Lemonade      1566  Stephen Little
#
#   CookTime PrepTime TotalTime         DatePublished  \
# 0    PT24H    PT45M  PT24H45M  1999-08-09T21:46:00Z
# 1    PT25M     PT4H   PT4H25M  1999-08-29T13:12:00Z
# 2     PT5M    PT30M     PT35M  1999-09-05T19:52:00Z
#
#                                          Description  \
# 0  Make and share this Low-Fat Berry Blue Frozen ...
# 1  Make and share this Biryani recipe from Food.com.
# 2  This is from one of my  first Good House Keepi...
#
#                                               Images  ... SaturatedFatContent  \
# 0  c("https://img.sndimg.com/food/image/upload/w_...  ...                 1.3
# 1  c("https://img.sndimg.com/food/image/upload/w_...  ...                16.6
# ...

# %%
ingredientsCount.head()
# Out:
#    Unnamed: 0  RecipeId  IngredientsCount
# 0           0        38                 4
# 1           1        39                25
# 2           2        40                 7
# 3           3        41                14
# 4           4        42                 5

# %%
minMaxMean.head()
# Out:
#    RecipeId  min  max      mean
# 0        38    4    5  4.250000
# 1        39    3    3  3.000000
# 2        40    1    5  4.333333
# 3        41    4    5  4.500000
# 4        42    0    5  2.666667

# %%
timeFormat.head()
# Out:
#    Unnamed: 0  RecipeId  CookTime  PrepTime  TotalTime
# 0           0        38      1440        45       1485
# 1           1        39        25       240        265
# 2           2        40         5        30         35
# 3           3        41        20      1440       1460
# 4           4        42        30        20         50

# %%
reviewclean.head()
# Out:
#    RecipeId Review_Class
# 0        38      average
# 1        39      average
# 2        40      average
# 3        41         good
# 4        42      average

# %%
# Remove Unnamed column from timeFormat and Ingredients datasets
ingredientsCount = ingredientsCount[['RecipeId','IngredientsCount']]
ingredientsCount.head()
# Out:
#    RecipeId  IngredientsCount
# 0        38                 4
# 1        39                25
# 2        40                 7
# 3        41                14
# 4        42                 5

# %%
timeFormat = pd.read_csv('C:/Users/SLL26/Desktop/Data Science and Analytics/CS5706 MACHINE LEARNING/CS5811 Coursework/Cleaned CSV/TimeFormat.csv')

# %%
timeFormat = timeFormat[['RecipeId','CookTime','PrepTime','TotalTime']]
timeFormat.head()
# Out:
#    RecipeId  CookTime  PrepTime  TotalTime
# 0        38      1440        45       1485
# 1        39        25       240        265
# 2        40         5        30         35
# 3        41        20      1440       1460
# 4        42        30        20         50

# %%
# Rename the column names for timeFormat
timeFormat=timeFormat.rename({'CookTime':'CookTimeMins','PrepTime':'PrepTimeMins','TotalTime':'TotalTimeMins'}, axis='columns')

# %%
# Merge the datasets with recipes datasets
recipeNew = recipes.merge(timeFormat, how='left', on='RecipeId')
recipeNew
# Out:
#         RecipeId                                              Name  \
# 0             38                 Low-Fat Berry Blue Frozen Dessert
# 1             39                                           Biryani
# 2             40                                     Best Lemonade
# 3             41                    Carina's Tofu-Vegetable Kebabs
# 4             42                                      Cabbage Soup
# ...          ...                                               ...
# 522512    541379                    Meg's Fresh Ginger Gingerbread
# 522513    541380  Roast Prime Rib au Poivre with Mixed Peppercorns
# 522514    541381                             Kirshwasser Ice Cream
# 522515    541382          Quick & Easy Asian Cucumber Salmon Rolls
# 522516    541383                           Spicy Baked Scotch Eggs
#
#           AuthorId      AuthorName CookTime PrepTime TotalTime  \
# 0             1533          Dancer    PT24H    PT45M  PT24H45M
# ...

# %%
recipeNew = recipeNew.merge(ingredientsCount, how = 'left', on = 'RecipeId')
recipeNew
# Out:
#         RecipeId                                              Name  \
# 0             38                 Low-Fat Berry Blue Frozen Dessert
# 1             39                                           Biryani
# 2             40                                     Best Lemonade
# 3             41                    Carina's Tofu-Vegetable Kebabs
# 4             42                                      Cabbage Soup
# ...          ...                                               ...
# 522512    541379                    Meg's Fresh Ginger Gingerbread
# 522513    541380  Roast Prime Rib au Poivre with Mixed Peppercorns
# 522514    541381                             Kirshwasser Ice Cream
# 522515    541382          Quick & Easy Asian Cucumber Salmon Rolls
# 522516    541383                           Spicy Baked Scotch Eggs
#
#           AuthorId      AuthorName CookTime PrepTime TotalTime  \
# 0             1533          Dancer    PT24H    PT45M  PT24H45M
# ...

# %%
recipeReview = recipeNew.merge(minMaxMean, how='left', on='RecipeId') 
recipeReview
# Out:
#         RecipeId                                              Name  \
# 0             38                 Low-Fat Berry Blue Frozen Dessert
# 1             39                                           Biryani
# 2             40                                     Best Lemonade
# 3             41                    Carina's Tofu-Vegetable Kebabs
# 4             42                                      Cabbage Soup
# ...          ...                                               ...
# 522512    541379                    Meg's Fresh Ginger Gingerbread
# 522513    541380  Roast Prime Rib au Poivre with Mixed Peppercorns
# 522514    541381                             Kirshwasser Ice Cream
# 522515    541382          Quick & Easy Asian Cucumber Salmon Rolls
# 522516    541383                           Spicy Baked Scotch Eggs
#
#           AuthorId      AuthorName CookTime PrepTime TotalTime  \
# 0             1533          Dancer    PT24H    PT45M  PT24H45M
# ...

# %%
reviewclean.sort_values('RecipeId')
# Out:
#         RecipeId Review_Class
# 0             38      average
# 1             39      average
# 2             40      average
# 3             41         good
# 4             42      average
# ...          ...          ...
# 271673    540899      average
# 271674    541001      average
# 271675    541030      average
# 271676    541195         good
# 271677    541298         good
#
# [271678 rows x 2 columns]

# %%
recipeReview = recipeReview.merge(reviewclean, how='left', on='RecipeId') 
recipeReview
# Out:
#         RecipeId                                              Name  \
# 0             38                 Low-Fat Berry Blue Frozen Dessert
# 1             39                                           Biryani
# 2             40                                     Best Lemonade
# 3             41                    Carina's Tofu-Vegetable Kebabs
# 4             42                                      Cabbage Soup
# ...          ...                                               ...
# 522512    541379                    Meg's Fresh Ginger Gingerbread
# 522513    541380  Roast Prime Rib au Poivre with Mixed Peppercorns
# 522514    541381                             Kirshwasser Ice Cream
# 522515    541382          Quick & Easy Asian Cucumber Salmon Rolls
# 522516    541383                           Spicy Baked Scotch Eggs
#
#           AuthorId      AuthorName CookTime PrepTime TotalTime  \
# 0             1533          Dancer    PT24H    PT45M  PT24H45M
# ...

# %%
recipeReview.to_csv('MasterData.csv')

# %%
recipeReview.shape
# Out:
# (522517, 36)
