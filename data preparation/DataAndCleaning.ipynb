# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np 
from pandas.api.types import is_string_dtype, is_numeric_dtype

# %%
data = pd.read_csv('C:/Users/SLL26/Desktop/Data Science and Analytics/CS5706 MACHINE LEARNING/CS5811 Coursework/main_data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  RecipeId                               Name  \
# 0           0        38  Low-Fat Berry Blue Frozen Dessert
# 1           1        39                            Biryani
# 2           2        40                      Best Lemonade
# 3           3        41     Carina's Tofu-Vegetable Kebabs
# 4           4        42                       Cabbage Soup
#
#                                               Images   RecipeCategory  \
# 0  c("https://img.sndimg.com/food/image/upload/w_...  Frozen Desserts
# 1  c("https://img.sndimg.com/food/image/upload/w_...   Chicken Breast
# 2  c("https://img.sndimg.com/food/image/upload/w_...        Beverages
# 3  c("https://img.sndimg.com/food/image/upload/w_...         Soy/Tofu
# 4  "https://img.sndimg.com/food/image/upload/w_55...        Vegetable
#
#    AggregatedRating  ReviewCount  Calories  FatContent  SaturatedFatContent  \
# 0               4.5          4.0     170.9         2.5                  1.3
# ...

# %%
data = data.drop(columns=['Unnamed: 0','AggregatedRating','ReviewCount'])

# %%
data.head()
# Out:
#    RecipeId                               Name  \
# 0        38  Low-Fat Berry Blue Frozen Dessert
# 1        39                            Biryani
# 2        40                      Best Lemonade
# 3        41     Carina's Tofu-Vegetable Kebabs
# 4        42                       Cabbage Soup
#
#                                               Images   RecipeCategory  \
# 0  c("https://img.sndimg.com/food/image/upload/w_...  Frozen Desserts
# 1  c("https://img.sndimg.com/food/image/upload/w_...   Chicken Breast
# 2  c("https://img.sndimg.com/food/image/upload/w_...        Beverages
# 3  c("https://img.sndimg.com/food/image/upload/w_...         Soy/Tofu
# 4  "https://img.sndimg.com/food/image/upload/w_55...        Vegetable
#
#    Calories  FatContent  SaturatedFatContent  CholesterolContent  \
# 0     170.9         2.5                  1.3                 8.0
# 1    1110.7        58.8                 16.6               372.8
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522517 entries, 0 to 522516
# Data columns (total 22 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   RecipeId             522517 non-null  int64
#  1   Name                 522517 non-null  object
#  2   Images               522516 non-null  object
#  3   RecipeCategory       521766 non-null  object
#  4   Calories             522517 non-null  float64
#  5   FatContent           522517 non-null  float64
#  6   SaturatedFatContent  522517 non-null  float64
#  7   CholesterolContent   522517 non-null  float64
#  8   SodiumContent        522517 non-null  float64
#  9   CarbohydrateContent  522517 non-null  float64
#  10  FiberContent         522517 non-null  float64
#  11  SugarContent         522517 non-null  float64
#  12  ProteinContent       522517 non-null  float64
#  13  RecipeServings       339606 non-null  float64
# ...

# %%
data.describe(include='all')
# Out:
#              RecipeId          Name        Images RecipeCategory  \
# count   522517.000000        522517        522516         521766
# unique            NaN        438188        165889            311
# top               NaN  Banana Bread  character(0)        Dessert
# freq              NaN           186        356620          62072
# mean    271821.436970           NaN           NaN            NaN
# std     155495.878422           NaN           NaN            NaN
# min         38.000000           NaN           NaN            NaN
# 25%     137206.000000           NaN           NaN            NaN
# 50%     271758.000000           NaN           NaN            NaN
# 75%     406145.000000           NaN           NaN            NaN
# max     541383.000000           NaN           NaN            NaN
#
#              Calories     FatContent  SaturatedFatContent  CholesterolContent  \
# count   522517.000000  522517.000000        522517.000000       522517.000000
# ...

# %%
#Uni-veriate
#check for null values in each column
data.isnull().sum()
# Out:
# RecipeId                    0
# Name                        0
# Images                      1
# RecipeCategory            751
# Calories                    0
# FatContent                  0
# SaturatedFatContent         0
# CholesterolContent          0
# SodiumContent               0
# CarbohydrateContent         0
# FiberContent                0
# SugarContent                0
# ProteinContent              0
# RecipeServings         182911
# CookTime                    0
# PrepTime                    0
# TotalTime                   0
# Review_Class           250843
# IngredientsCount            0
# minimum_rating         250843
# maximum_rating         250843
# mean_of_rating         250843
# dtype: int64

# %%
dataNoNA = data.dropna()

# %%
dataNoNA.isnull().sum()
# Out:
# RecipeId               0
# Name                   0
# Images                 0
# RecipeCategory         0
# Calories               0
# FatContent             0
# SaturatedFatContent    0
# CholesterolContent     0
# SodiumContent          0
# CarbohydrateContent    0
# FiberContent           0
# SugarContent           0
# ProteinContent         0
# RecipeServings         0
# CookTime               0
# PrepTime               0
# TotalTime              0
# Review_Class           0
# IngredientsCount       0
# minimum_rating         0
# maximum_rating         0
# mean_of_rating         0
# dtype: int64

# %%
print(data.shape)
print(dataNoNA.shape)
# Out:
# (522517, 22)
# (173526, 22)

# %%
#Add 1.5 x (IQR) to the third quartile. Any number greater than this is a suspected outlier
#df.time_diff.quantile([0.25,0.5,0.75])

for column in data:
    if is_numeric_dtype(data[column]):
        first = data[column].quantile(.25)
        third = data[column].quantile(.75)
        iqr = third-first
        value = (1.5*iqr)+third
        print(column+' : '+str(round(value,2)))
# Out:
# RecipeId : 809553.5
# Calories : 1061.45
# FatContent : 60.1
# SaturatedFatContent : 24.75
# CholesterolContent : 264.05
# SodiumContent : 1795.55
# CarbohydrateContent : 108.55
# FiberContent : 10.3
# SugarContent : 41.0
# ProteinContent : 57.25
# RecipeServings : 14.0
# CookTime : 97.5
# PrepTime : 35.0
# TotalTime : 145.0
# IngredientsCount : 17.5
# minimum_rating : 8.0
# maximum_rating : 5.0
# mean_of_rating : 6.5

# %%
dataClean = dataNoNA[(dataNoNA.Calories<=1061.45) & (dataNoNA.FatContent<=60.1) & (dataNoNA.SaturatedFatContent<=24.75)& (dataNoNA.CholesterolContent<=264.05)& (dataNoNA.SodiumContent<=1795.55)& (dataNoNA.CarbohydrateContent<=108.55)& (dataNoNA.FiberContent<=10.3)& (dataNoNA.SugarContent<=41)& (dataNoNA.ProteinContent<=57.25)]

# %%
dataClean.describe()
# Out:
#             RecipeId       Calories     FatContent  SaturatedFatContent  \
# count  142784.000000  142784.000000  142784.000000        142784.000000
# mean   225582.673038     273.996216      13.308811             5.072256
# std    141523.786465     169.161990      11.276998             5.031518
# min        38.000000       0.000000       0.000000             0.000000
# 25%    103594.750000     144.900000       4.600000             1.100000
# 50%    214348.000000     246.700000      10.600000             3.500000
# 75%    337293.750000     374.900000      19.300000             7.500000
# max    541001.000000    1059.500000      60.100000            24.700000
#
#        CholesterolContent  SodiumContent  CarbohydrateContent   FiberContent  \
# count       142784.000000  142784.000000        142784.000000  142784.000000
# mean            51.546764     400.800782            25.737275       2.386519
# std             55.691738     379.361168            19.214268       2.184583
# ...

# %%
dataClean.shape
# Out:
# (142784, 22)

# %%
dataCleanFinal = dataClean[(dataClean.TotalTime<=1440)]

# %%
dataCleanFinal.shape
# Out:
# (141993, 22)

# %%
plt.boxplot(dataCleanFinal.Calories)
plt.show()

# %%
plt.boxplot(dataCleanFinal.FatContent)
plt.show()

# %%
plt.scatter(dataCleanFinal['FatContent'],dataCleanFinal['Calories'],alpha=0.2)
plt.show()

# %%
plt.scatter(dataCleanFinal['TotalTime'],dataCleanFinal['IngredientsCount'],alpha=0.2,)
plt.show()
