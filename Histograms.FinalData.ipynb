# %%
# loading the needed libraries
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np 
from pandas.api.types import is_string_dtype, is_numeric_dtype
# %matplotlib inline

# %%
dataFinal=pd.read_csv("NewFinalSample.csv")

# %%
dataFinal.columns
# Out:
# Index(['RecipeId', 'Name', 'RecipeCategory', 'AggregatedRating', 'ReviewCount',
#        'Calories', 'FatContent', 'SaturatedFatContent', 'CholesterolContent',
#        'SodiumContent', 'CarbohydrateContent', 'FiberContent', 'SugarContent',
#        'ProteinContent', 'RecipeServings', 'CookTime', 'PrepTime', 'TotalTime',
#        'Review_Class', 'IngredientsCount', 'minimum_rating', 'maximum_rating',
#        'mean_of_rating'],
#       dtype='object')

# %%
dataFinal.head(2)
# Out:
#    RecipeId                           Name RecipeCategory  AggregatedRating  \
# 0    100335  Scrumptious Cheeseburger Ring  One Dish Meal               5.0
# 1    317485          Mom's Comfort Chicken  One Dish Meal               5.0
#
#    ReviewCount  Calories  FatContent  SaturatedFatContent  CholesterolContent  \
# 0          9.0     345.8        13.9                  6.3                71.3
# 1         15.0     305.5        15.9                  3.4                80.7
#
#    SodiumContent  ...  ProteinContent  RecipeServings  CookTime  PrepTime  \
# 0          839.7  ...            19.2             8.0        30        30
# 1         1073.1  ...            29.0             4.0        15        15
#
#    TotalTime  Review_Class  IngredientsCount  minimum_rating maximum_rating  \
# 0         60       average                 8             4.0            5.0
# 1         30       average                 9             4.0            5.0
#
#    mean_of_rating
# 0        4.777778
# ...

# %%
sns.histplot(x = 'RecipeId',data = dataFinal , kde =True )
# Out:
# <AxesSubplot:xlabel='RecipeId', ylabel='Count'>

# %%
sns.histplot(x = 'Calories',data = dataFinal , kde =True )
# Out:
# <AxesSubplot:xlabel='Calories', ylabel='Count'>

# %%
sns.histplot(x = 'FatContent',data = dataFinal , kde =True )
# Out:
# <AxesSubplot:xlabel='FatContent', ylabel='Count'>

# %%
sns.histplot(x = 'SaturatedFatContent',data = dataFinal , kde =True )
# Out:
# <AxesSubplot:xlabel='SaturatedFatContent', ylabel='Count'>

# %%
sns.histplot(x = 'CholesterolContent',data = dataFinal , kde =True )
# Out:
# <AxesSubplot:xlabel='CholesterolContent', ylabel='Count'>

# %%
sns.histplot(x = 'SodiumContent',data = dataFinal , kde =True )
# Out:
# <AxesSubplot:xlabel='SodiumContent', ylabel='Count'>

# %%
sns.histplot(x = 'CarbohydrateContent',data = dataFinal , kde =True )
# Out:
# <AxesSubplot:xlabel='CarbohydrateContent', ylabel='Count'>

# %%
sns.histplot(x = 'ProteinContent',data = dataFinal , kde =True )
# Out:
# <AxesSubplot:xlabel='ProteinContent', ylabel='Count'>

# %%
sns.histplot(x = 'ReviewCount',data = dataFinal)
# Out:
# <AxesSubplot:xlabel='ReviewCount', ylabel='Count'>

# %%
sns.histplot(x = 'minimum_rating',data = dataFinal)
# Out:
# <AxesSubplot:xlabel='minimum_rating', ylabel='Count'>

# %%
sns.histplot(x = 'maximum_rating',data = dataFinal)
# Out:
# <AxesSubplot:xlabel='maximum_rating', ylabel='Count'>

# %%
sns.histplot(x = 'mean_of_rating',data = dataFinal)
# Out:
# <AxesSubplot:xlabel='mean_of_rating', ylabel='Count'>

# %%
sns.histplot(x = 'AggregatedRating',data = dataFinal)
# Out:
# <AxesSubplot:xlabel='AggregatedRating', ylabel='Count'>

# %%
sns.histplot(x = 'ReviewCount',data = dataFinal)
# Out:
# <AxesSubplot:xlabel='ReviewCount', ylabel='Count'>

# %%
sns.histplot(x = 'CookTime',data = dataFinal)
# Out:
# <AxesSubplot:xlabel='CookTime', ylabel='Count'>

# %%
sns.histplot(x = 'PrepTime',data = dataFinal)
# Out:
# <AxesSubplot:xlabel='PrepTime', ylabel='Count'>

# %%
sns.histplot(x = 'TotalTime',data = dataFinal)
# Out:
# <AxesSubplot:xlabel='TotalTime', ylabel='Count'>

# %%
sns.histplot(x = 'Review_Class',data = dataFinal)
# Out:
# <AxesSubplot:xlabel='Review_Class', ylabel='Count'>
